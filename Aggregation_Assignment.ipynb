# %% [markdown]
# # Aggregations

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset occupation.csv from the folder or [here](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
#pd.read_csv("C:/Data Sets/(Class 5-Python - Assignments)/4. Aggregation/occupation.csv",sep="/t")
#From the system directory


#Through the URL
url="https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"
pd.read_csv(url)
# Out:
#     user_id|age|gender|occupation|zip_code
# 0                  1|24|M|technician|85711
# 1                       2|53|F|other|94043
# 2                      3|23|M|writer|32067
# 3                  4|24|M|technician|43537
# 4                       5|33|F|other|15213
# ..                                     ...
# 938                 939|26|F|student|33319
# 939           940|32|M|administrator|02215
# 940                 941|20|M|student|97229
# 941               942|48|F|librarian|78209
# 942                 943|22|M|student|77841
#
# [943 rows x 1 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
url="https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"
users = pd.read_csv(url,sep= '|' )
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
type(users)

#GroupBy
#users.groupby('occupation').age.mean()

#Pivot Table, I am going with Pivot Table for now for better organisation
users.pivot_table(columns= 'occupation', values='age',aggfunc='mean')
# Out:
# occupation  administrator     artist     doctor   educator  engineer  \
# age             38.746835  31.392857  43.571429  42.010526  36.38806
#
# occupation  entertainment  executive  healthcare  homemaker  lawyer  ...  \
# age             29.222222   38.71875     41.5625  32.571429   36.75  ...
#
# occupation  marketing       none     other  programmer    retired   salesman  \
# age         37.615385  26.555556  34.52381   33.121212  63.071429  35.666667
#
# occupation  scientist    student  technician     writer
# age         35.548387  22.081633   33.148148  36.311111
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least.
#
# Use numpy.where() to encode gender column.

# %%
users['male_ratio'] = np.where(users.gender=='M',1,0)
users
a =(users.groupby(['occupation']).male_ratio.sum()/users.groupby('occupation').male_ratio.count()).reset_index()
a.sort_values(['male_ratio'],ascending = False)
##np.where(users.gender=='M',0,1)
#ct.div(axis=)
# Out:
#        occupation  male_ratio
# 2          doctor    1.000000
# 4        engineer    0.970149
# 19     technician    0.962963
# 15        retired    0.928571
# 14     programmer    0.909091
# 6       executive    0.906250
# 17      scientist    0.903226
# 5   entertainment    0.888889
# 9          lawyer    0.833333
# 16       salesman    0.750000
# 3        educator    0.726316
# 18        student    0.693878
# 13          other    0.657143
# 11      marketing    0.615385
# 20         writer    0.577778
# 12           none    0.555556
# 0   administrator    0.544304
# 1          artist    0.535714
# 10      librarian    0.431373
# 7      healthcare    0.312500
# 8       homemaker    0.142857

# %% [raw]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').age.agg([np.min,np.max])

#When I run through Pivot Table, i am getting amax below amin, which does not make the output organised, kindly advice if
#alternative for that as well. Also getting more information that amin and amax.

#users.pivot_table(columns= 'occupation', values='age',aggfunc=[np.min,np.max]).transpose()
# Out:
#                amin  amax
# occupation
# administrator    21    70
# artist           19    48
# doctor           28    64
# educator         23    63
# engineer         22    70
# entertainment    15    50
# executive        22    69
# healthcare       22    62
# homemaker        20    50
# lawyer           21    53
# librarian        23    69
# marketing        24    55
# none             11    55
# other            13    64
# programmer       20    63
# retired          51    73
# salesman         18    66
# scientist        23    55
# student           7    42
# technician       21    55
# writer           18    60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation','gender'])['age'].agg(np.mean)

#users.pivot_table(columns = ['occupation'],index = 'gender', values = 'age').agg(np.mean)
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
#users.pivot_table(columns=['occupation'], values = 'age').agg(np.count)
pd.crosstab(index = users.occupation, columns = users.gender)
# Out:
# gender          F    M
# occupation
# administrator  36   43
# artist         13   15
# doctor          0    7
# educator       26   69
# engineer        2   65
# entertainment   2   16
# executive       3   29
# healthcare     11    5
# homemaker       6    1
# lawyer          2   10
# librarian      29   22
# marketing      10   16
# none            4    5
# other          36   69
# programmer      6   60
# retired         1   13
# salesman        3    9
# scientist       3   28
# student        60  136
# technician      1   26
# writer         19   26

# %%
#users.crosstab
#Percentages row wise and then divide it
